# %% [markdown]
# <a href="https://colab.research.google.com/github/MurphyKlein/CS4782_final_project/blob/main/notebook/main.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# We will first mount the google drive folder containing all of our data to this running google colab instance.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
BASE_DIR = "/content/drive/MyDrive/DL_Final_Project"

import os
print(os.listdir("/content/drive/MyDrive/DL_Final_Project"))
# Out:
# ['weather_data', 'electricity_data']

# %% [markdown]
# Now that we loaded the appropriate google drive content, we should inspect the csv files.

# %%
import pandas as pd

WEATHER_DIR = f"{BASE_DIR}/weather_data"

files = [f for f in os.listdir(WEATHER_DIR)]
print(files)

path = os.path.join(WEATHER_DIR, files[0])
df = pd.read_csv(path, encoding="latin1")

print(df.shape)
display(df.head())
print(df.dtypes)
# Out:
# ['mpi_roof_2025.csv']
# (52560, 22)
#              Date Time  p (mbar)  T (degC)  Tpot (K)  Tdew (degC)  rh (%)  \
# 0  01.01.2025 00:10:00    997.30     -1.56    271.80        -2.97    90.0
# 1  01.01.2025 00:20:00    997.05     -0.90    272.48        -2.66    87.8
# 2  01.01.2025 00:30:00    996.96     -0.51    272.88        -2.44    86.7
# 3  01.01.2025 00:40:00    996.77     -0.27    273.14        -2.26    86.3
# 4  01.01.2025 00:50:00    996.62     -0.09    273.33        -2.14    86.0
#
#    VPmax (mbar)  VPact (mbar)  VPdef (mbar)  sh (g/kg)  ...  wv (m/s)  \
# 0          5.45          4.90          0.54       3.06  ...      1.61
# 1          5.72          5.02          0.70       3.14  ...      1.71
# 2          5.89          5.10          0.78       3.19  ...      1.61
# 3          5.99          5.17          0.82       3.23  ...      1.86
# 4          6.07          5.22          0.85       3.26  ...      1.25
#
#    max. wv (m/s)  wd (deg)  rain (mm)  raining (s)  SWDR (W/m²)  \
# 0           3.87     148.9        0.0          0.0          0.0
# 1           3.05     145.6        0.0          0.0          0.0
# 2           3.31     146.9        0.0          0.0          0.0
# 3           2.93     137.0        0.0          0.0          0.0
# 4           2.23     131.3        0.0          0.0          0.0
#
#    PAR (µmol/m²/s)  max. PAR (µmol/m²/s)  Tlog (degC)  CO2 (ppm)
# 0              0.0                   0.0         6.24      456.9
# 1              0.0                   0.0         6.32      451.7
# 2              0.0                   0.0         6.46      451.0
# 3              0.0                   0.0         6.63      450.4
# 4              0.0                   0.0         6.82      450.4
#
# [5 rows x 22 columns]
# Date Time                object
# p (mbar)                float64
# T (degC)                float64
# Tpot (K)                float64
# Tdew (degC)             float64
# rh (%)                  float64
# VPmax (mbar)            float64
# VPact (mbar)            float64
# VPdef (mbar)            float64
# sh (g/kg)               float64
# H2OC (mmol/mol)         float64
# rho (g/m**3)            float64
# wv (m/s)                float64
# max. wv (m/s)           float64
# wd (deg)                float64
# rain (mm)               float64
# raining (s)             float64
# SWDR (W/m²)             float64
# PAR (µmol/m²/s)         float64
# max. PAR (µmol/m²/s)    float64
# Tlog (degC)             float64
# CO2 (ppm)               float64
# dtype: object

# %% [markdown]
# Now we have confirmed the proper dataset has been loaded in. Hooray!
